# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
books=pd.read_csv('books.csv')
users=pd.read_csv('users.csv')
ratings=pd.read_csv('ratings.csv')
# Out:
# C:\Users\Bhuvnesh's PC\AppData\Local\Temp\ipykernel_2720\1004906641.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books=pd.read_csv('books.csv')

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271359 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %%
ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
plt.hist(ratings['Book-Rating'])
plt.show()

# %%
ratings.groupby(ratings['ISBN']).count().sort_values(by='Book-Rating',ascending=False)[:400]
# Out:
#             User-ID  Book-Rating
# ISBN
# 0971880107     2502         2502
# 0316666343     1295         1295
# 0385504209      883          883
# 0060928336      732          732
# 0312195516      723          723
# ...             ...          ...
# 0671011367      143          143
# 0671708635      143          143
# 0767905385      143          143
# 0449221490      143          143
# 0312990456      142          142
#
# [400 rows x 2 columns]

# %%
ratings.groupby(ratings['ISBN']).sum('Book-Rating').sort_values(by='Book-Rating',ascending=False)
# Out:
#               User-ID  Book-Rating
# ISBN
# 0316666343  182243428         5787
# 0385504209  120940891         4108
# 0312195516   99657290         3134
# 0679781587   90867127         2800
# 059035342X   79852541         2798
# ...               ...          ...
# 082176690      101209            0
# 0394724844      63394            0
# 0821766937     907448            0
# 0821766945     213152            0
# 0930330668     198711            0
#
# [340556 rows x 2 columns]

# %%
ratings['Book-Rating'].value_counts()
# Out:
# 0     716109
# 8     103736
# 10     78610
# 7      76457
# 9      67541
# 5      50974
# 6      36924
# 4       8904
# 3       5996
# 2       2759
# 1       1770
# Name: Book-Rating, dtype: int64

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB

# %%
users
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   User-ID   278858 non-null  int64
#  1   Location  278858 non-null  object
#  2   Age       168096 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB

# %%
print(books.shape)
print(ratings.shape)
print(users.shape)
# Out:
# (271360, 8)
# (1149780, 3)
# (278858, 3)

# %% [markdown]
# # Popularity Recommender system

# %%
df1=ratings.merge(books,on='ISBN')

# %%
df1
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1           2313  034545104X            5
# 2           6543  034545104X            0
# 3           8680  034545104X            5
# 4          10314  034545104X            9
# ...          ...         ...          ...
# 1031131   276688  0517145553            0
# 1031132   276688  1575660792            7
# 1031133   276690  0590907301            0
# 1031134   276704  0679752714            0
# 1031135   276704  0806917695            5
#
#                                                 Book-Title      Book-Author  \
# 0                                     Flesh Tones: A Novel       M. J. Rose
# 1                                     Flesh Tones: A Novel       M. J. Rose
# 2                                     Flesh Tones: A Novel       M. J. Rose
# 3                                     Flesh Tones: A Novel       M. J. Rose
# ...

# %%
df2=df1[['Book-Title','Book-Rating']]

# %%
num_rating=df2.groupby(df2['Book-Title']).count()

# %%
fnum_rating=num_rating[num_rating['Book-Rating']>250]

# %%
fnum_rating
# Out:
#                                                     Book-Rating
# Book-Title
# 1984                                                        284
# 1st to Die: A Novel                                         509
# 2nd Chance                                                  356
# A Bend in the Road                                          346
# A Child Called \It\": One Child's Courage to Su...          265
# ...                                                         ...
# White Oleander : A Novel                                    387
# White Oleander : A Novel (Oprah's Book Club)                356
# Wicked: The Life and Times of the Wicked Witch ...          326
# Wild Animus                                                2502
# \O\" Is for Outlaw"                                         269
#
# [186 rows x 1 columns]

# %%
avg_rating=df2.groupby(df2['Book-Title']).mean()

# %%
avg_rating
# Out:
#                                                     Book-Rating
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...     2.250000
#  Always Have Popsicles                                 0.000000
#  Apple Magic (The Collector's series)                  0.000000
#  Ask Lily (Young Women of Faith: Lily Series, B...     8.000000
#  Beyond IBM: Leadership Marketing and Finance f...     0.000000
# ...                                                         ...
# Ã?Â?lpiraten.                                          0.000000
# Ã?Â?rger mit Produkt X. Roman.                         5.250000
# Ã?Â?sterlich leben.                                    7.000000
# Ã?Â?stlich der Berge.                                  2.666667
# Ã?Â?thique en toc                                      4.000000
#
# [241071 rows x 1 columns]

# %%
popularity=fnum_rating.merge(avg_rating,on='Book-Title').rename(columns={'Book-Rating_x':'num_rating',"Book-Rating_y":'avg_rating'})

# %%
popularity=popularity.sort_values('avg_rating',ascending=False)[0:51]

# %%
popularity=popularity.merge(df1,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','avg_rating','Image-URL-S','Book-Author','num_rating']]

# %%
popularity
# Out:
#                                               Book-Title  avg_rating  \
# 0      Harry Potter and the Prisoner of Azkaban (Book 3)    5.852804
# 428         Harry Potter and the Goblet of Fire (Book 4)    5.824289
# 815       Harry Potter and the Sorcerer's Stone (Book 1)    5.737410
# 1093   Harry Potter and the Order of the Phoenix (Boo...    5.501441
# 1440    Harry Potter and the Chamber of Secrets (Book 2)    5.183453
# 1996   The Hobbit : The Enchanting Prelude to The Lor...    5.007117
# 2277   The Fellowship of the Ring (The Lord of the Ri...    4.948370
# 2645   Harry Potter and the Sorcerer's Stone (Harry P...    4.895652
# 3220      The Two Towers (The Lord of the Rings, Part 2)    4.880769
# 3480                               To Kill a Mockingbird    4.700000
# 3990                                   The Da Vinci Code    4.642539
# 4888                  The Five People You Meet in Heaven    4.551163
# 5318                              The Catcher in the Rye    4.545657
# ...

# %% [markdown]
# # Collabrative Recommender system

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
ratings['ISBN'].unique().shape
# Out:
# (340556,)

# %%
books['ISBN'].unique().shape
# Out:
# (271360,)

# %%
books['Book-Title'].unique().shape
# Out:
# (242135,)

# %%
df_3=ratings.merge(books,on='ISBN')

# %%
df_4=df_3[['Book-Title','Book-Rating','User-ID']]

# %%
df_4
# Out:
#                                                 Book-Title  Book-Rating  \
# 0                                     Flesh Tones: A Novel            0
# 1                                     Flesh Tones: A Novel            5
# 2                                     Flesh Tones: A Novel            0
# 3                                     Flesh Tones: A Novel            5
# 4                                     Flesh Tones: A Novel            9
# ...                                                    ...          ...
# 1031131                                    Mostly Harmless            0
# 1031132                                        Gray Matter            7
# 1031133  Triplet Trouble and the Class Trip (Triplet Tr...            0
# 1031134  A Desert of Pure Feeling (Vintage Contemporaries)            0
# 1031135  Perplexing Lateral Thinking Puzzles: Scholasti...            5
#
#          User-ID
# 0         276725
# 1           2313
# 2           6543
# 3           8680
# ...

# %%
user_count=df_4.groupby(['User-ID']).count()

# %%
user_count1=user_count[user_count['Book-Title']>200]

# %%
temp=df_4.groupby('Book-Title').count()

# %%
ratings_count=temp[temp['User-ID']>50]
# Out:
#                                                     Book-Rating  User-ID
# Book-Title
# 10 Lb. Penalty                                               61       61
# 16 Lighthouse Road                                           65       65
# 1984                                                        284      284
# 1st to Die: A Novel                                         509      509
# 2010: Odyssey Two                                            90       90
# ...                                                         ...      ...
# Zen and the Art of Motorcycle Maintenance: An I...          210      210
# Zoya                                                        103      103
# \O\" Is for Outlaw"                                         269      269
# \Surely You're Joking, Mr. Feynman!\": Adventur...           57       57
# stardust                                                     51       51
#
# [2381 rows x 2 columns]

# %%
fin1=df_4.merge(user_count1,on='User-ID',how='inner')

# %%
fin2=fin1.drop(['Book-Title_y','Book-Rating_y'],axis=1).rename(columns={'Book-Title_x':'Book-Title','Book-Rating_x':'Book-Rating'})

# %%
fin2
# Out:
#                                     Book-Title  Book-Rating  User-ID
# 0                         Flesh Tones: A Novel            0     6543
# 1                    The Lovely Bones: A Novel            0     6543
# 2                            The Da Vinci Code            0     6543
# 3                                  Wild Animus            0     6543
# 4       Four To Score (A Stephanie Plum Novel)            0     6543
# ...                                        ...          ...      ...
# 474002                    Bold Land, Bold Love            0   133868
# 474003                            Suddenly You            0   133868
# 474004                               Heartless            8   133868
# 474005                    Shifting Calder Wind            0   133868
# 474006                       Ice &amp; Rapture            0   133868
#
# [474007 rows x 3 columns]

# %%
fin3=fin2.merge(,on='Book-Title',how='inner').drop(['User-ID_y','Book-Rating_y'],axis=1).rename(columns={'User-ID_x':'User-ID','Book-Rating_x':'Book-Rating'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2720\3589094587.py in ?()
# ----> 1 fin3=fin2.merge(ratings,on='Book-Title',how='inner').drop(['User-ID_y','Book-Rating_y'],axis=1).rename(columns={'User-ID_x':'User-ID','Book-Rating_x':'Book-Rating'})
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10089         validate: str | None = None,
#   10090     ) -> DataFrame:
#   10091         from pandas.core.reshape.merge import merge
#   10092
# > 10093         return merge(
#   10094             self,
#   10095             right,
#   10096             how=how,
#
# ...

# %%
fin4=fin3.merge(df_3,on=['Book-Title','User-ID'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 fin4=fin3.merge(df_3,on=['Book-Title','User-ID'])
#
# NameError: name 'fin3' is not defined

# %%
fin4=fin4.rename({'Book-Rating_x':'Book-Rating'},axis=1)

# %%
pt=fin4.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
pt.fillna(0,inplace=True)

# %%
pt

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity=cosine_similarity(pt)

# %%
similarity

# %%
def recommend(name):
    try:
        name=str(name)
        idx=np.where(pt.index==name)[0][0]
        rec_idx=some(idx)
        for i in rec_idx:
            print(pt.index[i])
    except IndexError:
        print('Movie not available')
def some(idx):
    vector=similarity[idx]
    sort_vect=sorted(enumerate(vector),reverse=True,key=lambda x: x[1])
    return [ x[0] for x in sort_vect[1:6]]

# %%
recommend('The Notebook')
